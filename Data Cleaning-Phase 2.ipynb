# %%
import pandas as pd 
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("gurgaon_properties.csv")

# %%
# make a temporary copy of the dataset 
temp_df = df.copy()

# %%
temp_df.shape
# Out:
# (3961, 20)

# %%
# check for duplicate values 
temp_df.duplicated().sum()
# Out:
# 0

# %%
# check for null values 
temp_df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
# check for overall information 
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   int64
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
# ...

# %%
# extract the sector from property name and create a sector column 
temp_df.insert(loc=3, column="sector", value=temp_df["property_name"].str.split('in').str.get(1).str.replace("Gurgaon", '').str.strip())

# %%
temp_df["sector"].value_counts()
# Out:
# Sohna                                                        163
# Sector 102                                                   113
# Sector 85                                                    110
# Sector 92                                                    104
# Sector 69                                                     94
# Sector 90                                                     90
# Sector 65                                                     90
# Sector 81                                                     90
# Sector 109                                                    88
# Sector 79                                                     80
# Sector 83                                                     69
# Sector 37D                                                    68
# Sector 86                                                     67
# Sector 104                                                    66
# ...

# %%
temp_df["sector"] = temp_df["sector"].str.lower()

# %%
temp_df["sector"].value_counts()
# Out:
# sohna                                                        163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
# sector 90                                                     90
# sector 65                                                     90
# sector 81                                                     90
# sector 109                                                    88
# sector 79                                                     80
# sector 83                                                     69
# sector 37d                                                    68
# sector 86                                                     67
# sector 104                                                    66
# ...

# %%
temp_df['sector'] = temp_df['sector'].str.replace('dharam colony','sector 12')
temp_df['sector'] = temp_df['sector'].str.replace('krishna colony','sector 7')
temp_df['sector'] = temp_df['sector'].str.replace('suncity','sector 54')
temp_df['sector'] = temp_df['sector'].str.replace('prem nagar','sector 13')
temp_df['sector'] = temp_df['sector'].str.replace('mg road','sector 28')
temp_df['sector'] = temp_df['sector'].str.replace('gandhi nagar','sector 28')
temp_df['sector'] = temp_df['sector'].str.replace('laxmi garden','sector 11')
temp_df['sector'] = temp_df['sector'].str.replace('shakti nagar','sector 11')
temp_df['sector'] = temp_df['sector'].str.replace('baldev nagar','sector 7')
temp_df['sector'] = temp_df['sector'].str.replace('shivpuri','sector 7')
temp_df['sector'] = temp_df['sector'].str.replace('garhi harsaru','sector 17')
temp_df['sector'] = temp_df['sector'].str.replace('imt manesar','manesar')
temp_df['sector'] = temp_df['sector'].str.replace('adarsh nagar','sector 12')
temp_df['sector'] = temp_df['sector'].str.replace('shivaji nagar','sector 11')
temp_df['sector'] = temp_df['sector'].str.replace('bhim nagar','sector 6')
temp_df['sector'] = temp_df['sector'].str.replace('madanpuri','sector 7')
temp_df['sector'] = temp_df['sector'].str.replace('saraswati vihar','sector 28')
temp_df['sector'] = temp_df['sector'].str.replace('arjun nagar','sector 8')
temp_df['sector'] = temp_df['sector'].str.replace('ravi nagar','sector 9')
temp_df['sector'] = temp_df['sector'].str.replace('vishnu garden','sector 105')
temp_df['sector'] = temp_df['sector'].str.replace('bhondsi','sector 11')
temp_df['sector'] = temp_df['sector'].str.replace('surya vihar','sector 21')
temp_df['sector'] = temp_df['sector'].str.replace('devilal colony','sector 9')
temp_df['sector'] = temp_df['sector'].str.replace('valley view estate','gwal pahari')
temp_df['sector'] = temp_df['sector'].str.replace('mehrauli  road','sector 14')
temp_df['sector'] = temp_df['sector'].str.replace('jyoti park','sector 7')
temp_df['sector'] = temp_df['sector'].str.replace('ansal plaza','sector 23')
temp_df['sector'] = temp_df['sector'].str.replace('dayanand colony','sector 6')
temp_df['sector'] = temp_df['sector'].str.replace('sushant lok phase 2','sector 55')
temp_df['sector'] = temp_df['sector'].str.replace('chakkarpur','sector 28')
temp_df['sector'] = temp_df['sector'].str.replace('greenwood city','sector 45')
temp_df['sector'] = temp_df['sector'].str.replace('subhash nagar','sector 12')
temp_df['sector'] = temp_df['sector'].str.replace('sohna road road','sohna road')
temp_df['sector'] = temp_df['sector'].str.replace('malibu town','sector 47')
temp_df['sector'] = temp_df['sector'].str.replace('surat nagar 1','sector 104')
temp_df['sector'] = temp_df['sector'].str.replace('new colony','sector 7')
temp_df['sector'] = temp_df['sector'].str.replace('mianwali colony','sector 12')
temp_df['sector'] = temp_df['sector'].str.replace('jacobpura','sector 12')
temp_df['sector'] = temp_df['sector'].str.replace('rajiv nagar','sector 13')
temp_df['sector'] = temp_df['sector'].str.replace('ashok vihar','sector 3')
temp_df['sector'] = temp_df['sector'].str.replace('dlf phase 1','sector 26')
temp_df['sector'] = temp_df['sector'].str.replace('nirvana country','sector 50')
temp_df['sector'] = temp_df['sector'].str.replace('palam vihar','sector 2')
temp_df['sector'] = temp_df['sector'].str.replace('dlf phase 2','sector 25')
temp_df['sector'] = temp_df['sector'].str.replace('sushant lok phase 1','sector 43')
temp_df['sector'] = temp_df['sector'].str.replace('laxman vihar','sector 4')
temp_df['sector'] = temp_df['sector'].str.replace('dlf phase 4','sector 28')
temp_df['sector'] = temp_df['sector'].str.replace('dlf phase 3','sector 24')
temp_df['sector'] = temp_df['sector'].str.replace('sushant lok phase 3','sector 57')
temp_df['sector'] = temp_df['sector'].str.replace('dlf phase 5','sector 43')
temp_df['sector'] = temp_df['sector'].str.replace('rajendra park','sector 105')
temp_df['sector'] = temp_df['sector'].str.replace('uppals southend','sector 49')
temp_df['sector'] = temp_df['sector'].str.replace('sohna','sohna road')
temp_df['sector'] = temp_df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
temp_df['sector'] = temp_df['sector'].str.replace('south city 1','sector 41')
temp_df['sector'] = temp_df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
temp_df["sector"].value_counts()
# Out:
# sohna road                                                   163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
# sector 90                                                     90
# sector 81                                                     90
# sector 65                                                     90
# sector 109                                                    88
# sector 79                                                     80
# sector 104                                                    73
# sector 83                                                     69
# sector 37d                                                    68
# sector 86                                                     67
# ...

# %%
# temp_df["sector"] = temp_df["sector"][temp_df["sector"].str.contains("block")].str.split('block').str.get(1).str.strip()

# %%
temp_df["sector"][temp_df["sector"].str.contains("block")] = temp_df["sector"][temp_df["sector"].str.contains("block")].str.split('block').str.get(1).str.strip()
# Out:
# C:\Users\Omkar\AppData\Local\Temp\ipykernel_10384\3705375384.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df["sector"][temp_df["sector"].str.contains("block")] = temp_df["sector"][temp_df["sector"].str.contains("block")].str.split('block').str.get(1).str.strip()

# %%
temp_df["sector"].value_counts()
# Out:
# sohna road                                                   163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
# sector 81                                                     90
# sector 65                                                     90
# sector 90                                                     90
# sector 109                                                    88
# sector 79                                                     80
# sector 104                                                    73
# sector 83                                                     69
# sector 37d                                                    68
# sector 43                                                     67
# ...

# %%
# dropping some of the rows where the sector information is not mentioned 
a = temp_df["sector"].value_counts()[temp_df["sector"].value_counts() >= 3]

# %%
temp_df = temp_df[temp_df["sector"].isin(a.index)]

# %%
temp_df.shape
# Out:
# (3805, 21)

# %%
temp_df["sector"].value_counts()
# Out:
# sohna road                    163
# sector 102                    113
# sector 85                     110
# sector 92                     104
# sector 69                      94
# sector 81                      90
# sector 90                      90
# sector 65                      90
# sector 109                     88
# sector 79                      80
# sector 104                     73
# sector 83                      69
# sector 37d                     68
# sector 43                      67
# sector 86                      67
# sector 50                      65
# sector 107                     60
# sector 108                     59
# sector 95                      57
# sector 56                      57
# sector 48                      56
# sector 89                      56
# sector 2                       55
# sector 70a                     54
# sector 70                      53
# sector 37c                     53
# sector-33 sohna road           51
# ...

# %%
temp_df["sector"] = temp_df["sector"].str.replace("sector 37d", "sector 37")
temp_df["sector"] = temp_df["sector"].str.replace("sector 70a", "sector 70")
temp_df["sector"] = temp_df["sector"].str.replace("sector 37c", "sector 37")
temp_df["sector"] = temp_df["sector"].str.replace("sector-33 sohna road", "sector 33")
temp_df["sector"] = temp_df["sector"].str.replace("sector 88a", "sector 88")
temp_df["sector"] = temp_df["sector"].str.replace("sector 67a", "sector 67")
temp_df["sector"] = temp_df["sector"].str.replace("sector 82a", "sector 82")
temp_df["sector"] = temp_df["sector"].str.replace("gwal pahari", "sector 54")
temp_df["sector"] = temp_df["sector"].str.replace("sector 1 manesar", "sector 1")
temp_df["sector"] = temp_df["sector"].str.replace("sector 4 phase 2", "sector 4")
temp_df["sector"] = temp_df["sector"].str.replace("sohna road road", "sohna road") 
temp_df["sector"] = temp_df["sector"].str.replace("sector 3 phase 3 extension", "sector 3") 
temp_df["sector"] = temp_df["sector"].str.replace("sector 9a", "sector 9") 
temp_df["sector"] = temp_df["sector"].str.replace("sector 1a manesar", "sector 1") 
temp_df["sector"] = temp_df["sector"].str.replace("sector 95a", "sector 95")
temp_df["sector"] = temp_df["sector"].str.replace("sector 89 a", "sector 89")
temp_df["sector"] = temp_df["sector"].str.replace("sector 2 extension", "sector 2")
temp_df["sector"] = temp_df["sector"].str.replace("sector 36 sohna road", "sector 36")
temp_df["sector"] = temp_df["sector"].str.replace("sector 23a", "sector 23")
temp_df["sector"] = temp_df["sector"].str.replace("new sector 2", "sector 2")
temp_df["sector"] = temp_df["sector"].str.replace("sector 12a", "sector 12")
temp_df["sector"] = temp_df["sector"].str.replace("sector 3a", "sector 3")
temp_df["sector"] = temp_df["sector"].str.replace("maruti kunj", "sector 12")
temp_df["sector"] = temp_df["sector"].str.replace("sector 17b", "sector 17")
temp_df["sector"] = temp_df["sector"].str.replace("sector 110 a", "sector 110")
temp_df["sector"] = temp_df["sector"].str.replace("sector 88b", "sector 88")
temp_df["sector"] = temp_df["sector"].str.replace("patel nagar", "sector 15") 
temp_df["sector"] = temp_df["sector"].str.replace("sector 17a", "sector 17")

# %%
temp_df["sector"].value_counts()
# Out:
# sohna road           175
# sector 37            121
# sector 102           113
# sector 85            110
# sector 70            107
# sector 92            104
# sector 69             94
# sector 65             90
# sector 90             90
# sector 81             90
# sector 109            88
# sector 79             80
# sector 33             74
# sector 104            73
# sector 67             70
# sector 83             69
# sector 2              68
# sector 86             67
# sector 43             67
# sector 95             66
# sector 50             65
# sector 89             64
# sector 82             62
# sector 107            60
# sector 108            59
# sector 56             57
# sector 48             56
# sector 84             51
# sector 26             50
# sector 4              49
# sector 54             49
# sector 49             48
# sector 28             47
# sector 66             46
# sector 103            45
# sector 113            43
# sector 25             43
# ...

# %%
temp_df[temp_df["sector"] == "new"]
# Out:
#                   property_name property_type                       society  \
# 1312  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 1397  4 BHK Flat in New Gurgaon          flat                    sare homes
# 2480  2 BHK Flat in New Gurgaon          flat                   green court
# 3515  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
#
#      sector  price  price_per_sqft    area  \
# 1312    new   4.00         11428.0  3500.0
# 1397    new   0.85          4786.0  1776.0
# 2480    new   0.38          5507.0   690.0
# 3515    new   0.67          5583.0  1200.0
#
#                                 areaWithType  bedRoom  bathroom  balcony  \
# 1312        Carpet area: 3500 (325.16 sq.m.)        4         4        2
# 1397     Super Built up area 1776(165 sq.m.)        4         4        3
# 2480           Carpet area: 690 (64.1 sq.m.)        2         2        1
# ...

# %%
temp_df.loc[1312, 'sector'] = 'sector 37'
temp_df.loc[1397, 'sector'] = 'sector 92'
temp_df.loc[2480, 'sector'] = 'sector 90'
temp_df.loc[3515, 'sector'] = 'sector 76'

# %%
temp_df["sector"].value_counts()
# Out:
# sohna road           175
# sector 37            122
# sector 102           113
# sector 85            110
# sector 70            107
# sector 92            105
# sector 69             94
# sector 90             91
# sector 65             90
# sector 81             90
# sector 109            88
# sector 79             80
# sector 33             74
# sector 104            73
# sector 67             70
# sector 83             69
# sector 2              68
# sector 43             67
# sector 86             67
# sector 95             66
# sector 50             65
# sector 89             64
# sector 82             62
# sector 107            60
# sector 108            59
# sector 56             57
# sector 48             56
# sector 84             51
# sector 26             50
# sector 54             49
# sector 4              49
# sector 49             48
# sector 28             47
# sector 66             46
# sector 103            45
# sector 113            43
# sector 25             43
# ...

# %%
temp_df["sector"] = temp_df["sector"].str.replace("sector 99a", "sector 99")
temp_df["sector"] = temp_df["sector"].str.replace("sector 63a", "sector 63")
temp_df["sector"] = temp_df["sector"].str.replace("sector 36a", "sector 36")
temp_df["sector"] = temp_df["sector"].str.replace("sector 10a", "sector 10")

# %%
temp_df["sector"].value_counts()
# Out:
# sohna road           175
# sector 37            122
# sector 102           113
# sector 85            110
# sector 70            107
# sector 92            105
# sector 69             94
# sector 90             91
# sector 65             90
# sector 81             90
# sector 109            88
# sector 79             80
# sector 33             74
# sector 104            73
# sector 67             70
# sector 83             69
# sector 2              68
# sector 43             67
# sector 86             67
# sector 95             66
# sector 50             65
# sector 89             64
# sector 82             62
# sector 107            60
# sector 108            59
# sector 56             57
# sector 48             56
# sector 84             51
# sector 26             50
# sector 54             49
# sector 4              49
# sector 49             48
# sector 99             48
# sector 28             47
# sector 66             46
# sector 103            45
# sector 113            43
# ...

# %%
temp_df.head()
# Out:
#                                        property_name property_type  \
# 0                    3 BHK Flat in Sector 90 Gurgaon          flat
# 1                    3 BHK Flat in Sector 90 Gurgaon          flat
# 2                    4 BHK Flat in Sector 92 Gurgaon          flat
# 3  2 Bedroom House for sale in Palam Vihar Extension         house
# 4                    3 BHK Flat in Sector 92 Gurgaon          flat
#
#                                    society     sector  price  price_per_sqft  \
# 0                     shree vardhman flora  sector 90   0.96          5120.0
# 1                     dlf new town heights  sector 90   1.30          6735.0
# 2  sare crescent parc royal greens phase 1  sector 92   1.25          5832.0
# 3      palam vihar extension west zone rwa   sector 2   0.35          6481.0
# 4                               sare homes  sector 92   0.68          5238.0
#
#      area                                       areaWithType  bedRoom  \
# ...

# %%
# features to drop -> property_name, address, description, rating
temp_df.drop(columns=['property_name', 'address', 'description', 'rating'], inplace=True)

# %%
temp_df.head()
# Out:
#   property_type                                  society     sector  price  \
# 0          flat                     shree vardhman flora  sector 90   0.96
# 1          flat                     dlf new town heights  sector 90   1.30
# 2          flat  sare crescent parc royal greens phase 1  sector 92   1.25
# 3         house      palam vihar extension west zone rwa   sector 2   0.35
# 4          flat                               sare homes  sector 92   0.68
#
#    price_per_sqft    area                                       areaWithType  \
# 0          5120.0  1875.0             Super Built up area 1875(174.19 sq.m.)
# 1          6735.0  1930.0  Super Built up area 1930(179.3 sq.m.)Built Up ...
# 2          5832.0  2143.0             Super Built up area 2143(199.09 sq.m.)
# 3          6481.0   540.0  Plot area 600(55.74 sq.m.)Carpet area: 540 sq....
# 4          5238.0  1298.0                   Carpet area: 1298 (120.59 sq.m.)
#
# ...

# %%
temp_df.duplicated().sum()
# Out:
# 122

# %%
# export the dataset 
temp_df.to_csv("flats_house_cleaned_phase2.csv", index=False)

# %%
df = pd.read_csv("flats_house_cleaned_phase2.csv")

# %%
df.sample(5)
# Out:
#      property_type                   society      sector  price  \
# 2171          flat  pareena coban residences   sector 99   1.13
# 2375          flat          ansal heights 86   sector 86   0.67
# 2142          flat     bestech spa signature   sector 81   4.40
# 480          house           bhawani enclave   sector 12   0.42
# 3569          flat    puri diplomatic greens  sector 111   3.90
#
#       price_per_sqft    area  \
# 2171          5658.0  1997.0
# 2375          5100.0  1314.0
# 2142         12571.0  3500.0
# 480           8235.0   510.0
# 3569         13000.0  3000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2171  Super Built up area 1997(185.53 sq.m.)Built Up...        3         5
# 2375             Super Built up area 1360(126.35 sq.m.)        2         2
# 2142  Super Built up area 4200(390.19 sq.m.)Built Up...        4         4
# 480   Plot area 565(52.49 sq.m.)Carpet area: 510 sq....        3         3
# ...

# %%
temp_df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'additionalRoom',
#        'floorNum', 'facing', 'agePossession', 'nearbyLocations',
#        'furnishDetails', 'features'],
#       dtype='object')

# %% [markdown]
# #### areaWithType, nearbyLocations, furnishDetails, features these column needs feature engineering
